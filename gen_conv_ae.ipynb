# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision import datasets, transforms

from utils import mnist, plot_graphs, plot_mnist
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
mnist_transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.5,), (0.5,)),
           ])

# %%
def mnist(batch_size=50, valid=0, shuffle=True, transform=mnist_transform, path='./MNIST_data'):
    test_data = datasets.MNIST(path, train=False, download=True, transform=transform)
    test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)
    
    train_data = datasets.MNIST(path, train=True, download=True, transform=transform)
    if valid > 0:
        num_train = len(train_data)
        indices = list(range(num_train))
        split = num_train-valid
        np.random.shuffle(indices)

        train_idx, valid_idx = indices[:split], indices[split:]
        train_sampler = SubsetRandomSampler(train_idx)
        valid_sampler = SubsetRandomSampler(valid_idx)

        train_loader = DataLoader(train_data, batch_size=batch_size, sampler=train_sampler)
        valid_loader = DataLoader(train_data, batch_size=batch_size, sampler=valid_sampler)
    
        return train_loader, valid_loader, test_loader
    else:
        train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=shuffle)
        return train_loader, test_loader

# %%
train_loader, valid_loader, test_loader = mnist(valid=10000, transform=mnist_transform)

# %%
class Encoder(nn.Module):
    def __init__(self, latent_size=10):
        super(Encoder, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, stride=2)
        self.conv2 = nn.Conv2d(32, 64, 3, stride=2)
        self.latent = nn.Linear(64*6*6, latent_size)
#         self.linear1 = nn.Linear(28*28, 256)
#         self.lin_mean = nn.Linear(256, latent_size)
#         self.lin_std = nn.Linear(256, latent_size)
    
    def forward(self, x):
        imput_batch_size = x.shape[0]
#         print(x.shape)
        x = torch.relu(self.conv1(x))
#         print(x.shape)
        x = torch.relu(self.conv2(x))
#         print(x.shape)
        x = torch.reshape(x, (imput_batch_size, -1))
#         print(x.shape)
#         x = torch.relu(self.linear1(x))
#         print(x.shape)
        return self.latent(x)
    
class Decoder(nn.Module):
    def __init__(self, latent_size=10):
        super(Decoder, self).__init__()
        self.lin = nn.Linear(latent_size, 64*6*6)
        self.deconv1 = nn.ConvTranspose2d(64, 32, 3, stride=2)
        self.deconv2 = nn.ConvTranspose2d(32, 1, 3, stride=2, output_padding=1)
#         self.linear1 = nn.Linear(latent_size, 256)
#         self.linear2 = nn.Linear(256, 28*28)
    
    def forward(self, x):
        imput_batch_size = x.shape[0]
#         print(x.shape)
        x = torch.relu(self.lin(x))
#         print(x.shape)
        x = torch.reshape(x, (imput_batch_size, 64, 6, 6))
#         print(x.shape)
        x = torch.relu(self.deconv1(x))
#         print(x.shape)
        x = torch.tanh(self.deconv2(x))
#         print(x.shape)
#         x = torch.relu(self.linear1(x))
#         x = torch.tanh(self.linear2(x))
#         x = torch.reshape(x, (imput_batch_size, 1, 28, 28))
        return x

# %%
class Net(nn.Module):
    def __init__(self, latent_size=16, loss_fn=F.mse_loss, lr=1e-4, l2=0.):
        super(Net, self).__init__()
        self.latent_size = latent_size
        self.E = Encoder(latent_size)
        self.D = Decoder(latent_size)
        self.loss_fn = loss_fn
        self.latent = None
        self._loss = None
        self._latent_loss = None
        self.optim = optim.Adam(self.parameters(), lr=lr, weight_decay=l2)
        
    def forward(self, x):
        self.latent = self.E(x)
        
#         epsilon = torch.randn_like(self.z_mean)
#         z = self.z_mean + torch.sqrt(torch.exp(self.z_log_sigma_sq)) * epsilon
        
        out = self.D(self.latent)
        return out
    
    def decode(self, h):
        with torch.no_grad():
            return self.D(h)
    
    def latent_loss(self):
        epsilon = torch.randn_like(self.latent)
        self._latent_loss = self.loss_fn(epsilon, self.latent)
#         self._latent_loss = torch.mean(self._latent_loss)
        return self._latent_loss
    
    def loss(self, x, target, **kwargs):
        self._loss = 28*28*self.loss_fn(x, target, **kwargs)
#         self._loss = self.loss_fn(x, target, **kwargs)
        return self._loss

# %%
models = {'net': Net(2)}
train_log = {k: [] for k in models}
test_log = {k: [] for k in models}

# %%
def train(epoch, models, log=None, noisy=False, zero_half=False):
    train_size = len(train_loader.sampler)
    for batch_idx, (data, _) in enumerate(train_loader):
        
        train_data = torch.Tensor(np.copy(data))
        if noisy:
            train_data += torch.randn_like(data)           
        if zero_half:
            train_data[:, :, :, :14] = 0                
        
        for model in models.values():
            model.optim.zero_grad()
            output = model(train_data)
            latent_loss = model.latent_loss()
            loss = model.loss(output, data) + latent_loss
            loss.backward()
            model.optim.step()
            
        if batch_idx % 200 == 0:
            line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
                epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
            l_str = '{}: reconstruction - {:.6f}, latent - {:.6f}'
            losses = ' '.join([l_str.format(k, m._loss.item(), m._latent_loss) for k, m in models.items()])
            print(line + losses)
            
    else:
        batch_idx += 1
        line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
            epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
        l_str = '{}: reconstruction - {:.6f}, latent - {:.6f}'
        losses = ' '.join([l_str.format(k, m._loss.item(), m._latent_loss) for k, m in models.items()])
        if log is not None:
            for k in models:
                log[k].append((models[k]._loss, models[k]._latent_loss))
        print(line + losses)

# %%
avg_lambda = lambda l: 'loss: {:.6f}'.format(l)
latent_lambda = lambda p: 'latent_loss: {:.6f}'.format(p)
line = lambda i, l, p: '{}: '.format(i) + avg_lambda(l) + '\t' + latent_lambda(p)
    
def test(models, loader, log=None):
    test_size = len(loader.sampler)


    test_loss = {k: 0. for k in models}
    latent_loss = {k: 0. for k in models}
    with torch.no_grad():
        for data, _ in loader:
            output = {k: m(data) for k, m in models.items()}
            for k, m in models.items():
                test_loss[k] += m.loss(output[k], data, reduction='sum').item() # sum up batch loss
                latent_loss[k] += m.latent_loss()
    
    for k in models:
        test_loss[k] /= (test_size * 784)
        latent_loss[k] /= (test_size * models[k].latent_size)
        if log is not None:
            log[k].append((test_loss[k], latent_loss[k]))
    
    lines = '\n'.join([line(k, test_loss[k], latent_loss[k]) for k in models]) + '\n'
    report = 'Test set:\n' + lines        
    print(report)

# %%
for epoch in range(1, 41):
    for model in models.values():
        model.train()
    train(epoch, models, train_log)
    for model in models.values():
        model.eval()
    test(models, valid_loader, test_log)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Losses net: reconstruction - 1142.740601, latent - 0.865265
# Train Epoch: 1 [10000/50000 (20%)]	Losses net: reconstruction - 400.152435, latent - 20.476427
# Train Epoch: 1 [20000/50000 (40%)]	Losses net: reconstruction - 330.851532, latent - 16.301874
# Train Epoch: 1 [30000/50000 (60%)]	Losses net: reconstruction - 301.857910, latent - 14.698258
# Train Epoch: 1 [40000/50000 (80%)]	Losses net: reconstruction - 302.283997, latent - 10.774584
# Train Epoch: 1 [50000/50000 (100%)]	Losses net: reconstruction - 284.801514, latent - 9.272079
# Test set:
# net: loss: 281.956073	latent_loss: 0.100377
#
# Train Epoch: 2 [0/50000 (0%)]	Losses net: reconstruction - 285.228485, latent - 9.607144
# Train Epoch: 2 [10000/50000 (20%)]	Losses net: reconstruction - 280.830811, latent - 8.221343
# Train Epoch: 2 [20000/50000 (40%)]	Losses net: reconstruction - 266.362671, latent - 9.460284
# Train Epoch: 2 [30000/50000 (60%)]	Losses net: reconstruction - 259.597595, latent - 7.588651
# Train Epoch: 2 [40000/50000 (80%)]	Losses net: reconstruction - 265.139008, latent - 6.366885
# Train Epoch: 2 [50000/50000 (100%)]	Losses net: reconstruction - 253.815521, latent - 6.101534
# Test set:
# net: loss: 257.273147	latent_loss: 0.061117
#
# Train Epoch: 3 [0/50000 (0%)]	Losses net: reconstruction - 248.182968, latent - 5.425363
# Train Epoch: 3 [10000/50000 (20%)]	Losses net: reconstruction - 242.966187, latent - 7.324849
# Train Epoch: 3 [20000/50000 (40%)]	Losses net: reconstruction - 247.288025, latent - 5.178693
# Train Epoch: 3 [30000/50000 (60%)]	Losses net: reconstruction - 257.484467, latent - 4.562809
# Train Epoch: 3 [40000/50000 (80%)]	Losses net: reconstruction - 240.542282, latent - 4.792267
# Train Epoch: 3 [50000/50000 (100%)]	Losses net: reconstruction - 246.967316, latent - 4.023714
# Test set:
# net: loss: 240.021508	latent_loss: 0.045361
#
# Train Epoch: 4 [0/50000 (0%)]	Losses net: reconstruction - 236.058792, latent - 3.429689
# Train Epoch: 4 [10000/50000 (20%)]	Losses net: reconstruction - 242.641724, latent - 4.311321
# Train Epoch: 4 [20000/50000 (40%)]	Losses net: reconstruction - 230.927429, latent - 4.241796
# Train Epoch: 4 [30000/50000 (60%)]	Losses net: reconstruction - 223.192352, latent - 4.056344
# Train Epoch: 4 [40000/50000 (80%)]	Losses net: reconstruction - 225.659866, latent - 3.330328
# Train Epoch: 4 [50000/50000 (100%)]	Losses net: reconstruction - 216.386261, latent - 3.673496
# Test set:
# net: loss: 225.235697	latent_loss: 0.038311
#
# Train Epoch: 5 [0/50000 (0%)]	Losses net: reconstruction - 232.421585, latent - 4.587030
# Train Epoch: 5 [10000/50000 (20%)]	Losses net: reconstruction - 214.563553, latent - 3.471076
# Train Epoch: 5 [20000/50000 (40%)]	Losses net: reconstruction - 223.286392, latent - 3.279432
# Train Epoch: 5 [30000/50000 (60%)]	Losses net: reconstruction - 222.456711, latent - 3.654809
# Train Epoch: 5 [40000/50000 (80%)]	Losses net: reconstruction - 224.816925, latent - 2.869631
# Train Epoch: 5 [50000/50000 (100%)]	Losses net: reconstruction - 212.600586, latent - 2.945519
# Test set:
# net: loss: 212.564511	latent_loss: 0.032765
#
# Train Epoch: 6 [0/50000 (0%)]	Losses net: reconstruction - 212.409866, latent - 3.562241
# Train Epoch: 6 [10000/50000 (20%)]	Losses net: reconstruction - 204.989883, latent - 3.199351
# Train Epoch: 6 [20000/50000 (40%)]	Losses net: reconstruction - 196.482559, latent - 3.101085
# Train Epoch: 6 [30000/50000 (60%)]	Losses net: reconstruction - 203.896164, latent - 3.819998
# Train Epoch: 6 [40000/50000 (80%)]	Losses net: reconstruction - 209.799271, latent - 2.971807
# Train Epoch: 6 [50000/50000 (100%)]	Losses net: reconstruction - 205.693863, latent - 3.368771
# Test set:
# net: loss: 201.504267	latent_loss: 0.030102
#
# Train Epoch: 7 [0/50000 (0%)]	Losses net: reconstruction - 200.022385, latent - 2.441454
# Train Epoch: 7 [10000/50000 (20%)]	Losses net: reconstruction - 195.459305, latent - 2.634336
# Train Epoch: 7 [20000/50000 (40%)]	Losses net: reconstruction - 208.322906, latent - 2.849282
# Train Epoch: 7 [30000/50000 (60%)]	Losses net: reconstruction - 191.357483, latent - 3.636837
# Train Epoch: 7 [40000/50000 (80%)]	Losses net: reconstruction - 185.603531, latent - 3.019141
# Train Epoch: 7 [50000/50000 (100%)]	Losses net: reconstruction - 190.547989, latent - 2.951581
# Test set:
# net: loss: 192.084379	latent_loss: 0.028489
#
# Train Epoch: 8 [0/50000 (0%)]	Losses net: reconstruction - 198.302826, latent - 2.942921
# Train Epoch: 8 [10000/50000 (20%)]	Losses net: reconstruction - 181.024384, latent - 2.819903
# Train Epoch: 8 [20000/50000 (40%)]	Losses net: reconstruction - 188.747971, latent - 3.114909
# Train Epoch: 8 [30000/50000 (60%)]	Losses net: reconstruction - 188.530289, latent - 2.584762
# Train Epoch: 8 [40000/50000 (80%)]	Losses net: reconstruction - 182.097672, latent - 3.081532
# Train Epoch: 8 [50000/50000 (100%)]	Losses net: reconstruction - 186.236191, latent - 3.083983
# Test set:
# net: loss: 183.991528	latent_loss: 0.027611
#
# Train Epoch: 9 [0/50000 (0%)]	Losses net: reconstruction - 195.377701, latent - 2.883914
# Train Epoch: 9 [10000/50000 (20%)]	Losses net: reconstruction - 180.082291, latent - 3.121720
# Train Epoch: 9 [20000/50000 (40%)]	Losses net: reconstruction - 170.336884, latent - 3.287208
# Train Epoch: 9 [30000/50000 (60%)]	Losses net: reconstruction - 186.065536, latent - 3.056804
# Train Epoch: 9 [40000/50000 (80%)]	Losses net: reconstruction - 172.006134, latent - 3.061702
# Train Epoch: 9 [50000/50000 (100%)]	Losses net: reconstruction - 164.452881, latent - 2.659560
# Test set:
# net: loss: 177.328889	latent_loss: 0.027044
#
# Train Epoch: 10 [0/50000 (0%)]	Losses net: reconstruction - 188.034729, latent - 2.254925
# Train Epoch: 10 [10000/50000 (20%)]	Losses net: reconstruction - 187.215973, latent - 2.259514
# Train Epoch: 10 [20000/50000 (40%)]	Losses net: reconstruction - 178.796539, latent - 3.125923
# Train Epoch: 10 [30000/50000 (60%)]	Losses net: reconstruction - 165.582413, latent - 2.534362
# Train Epoch: 10 [40000/50000 (80%)]	Losses net: reconstruction - 177.521133, latent - 2.564677
# Train Epoch: 10 [50000/50000 (100%)]	Losses net: reconstruction - 165.376831, latent - 2.659672
# Test set:
# net: loss: 171.482917	latent_loss: 0.026614
#
# Train Epoch: 11 [0/50000 (0%)]	Losses net: reconstruction - 175.018967, latent - 2.478462
# Train Epoch: 11 [10000/50000 (20%)]	Losses net: reconstruction - 172.808365, latent - 2.536827
# Train Epoch: 11 [20000/50000 (40%)]	Losses net: reconstruction - 159.448380, latent - 2.894345
# Train Epoch: 11 [30000/50000 (60%)]	Losses net: reconstruction - 172.338867, latent - 2.880208
# Train Epoch: 11 [40000/50000 (80%)]	Losses net: reconstruction - 164.074448, latent - 2.997846
# Train Epoch: 11 [50000/50000 (100%)]	Losses net: reconstruction - 176.094437, latent - 1.881984
# Test set:
# net: loss: 167.017635	latent_loss: 0.025236
#
# Train Epoch: 12 [0/50000 (0%)]	Losses net: reconstruction - 155.416168, latent - 2.643217
# Train Epoch: 12 [10000/50000 (20%)]	Losses net: reconstruction - 159.480713, latent - 2.508486
# Train Epoch: 12 [20000/50000 (40%)]	Losses net: reconstruction - 173.936020, latent - 2.389446
# Train Epoch: 12 [30000/50000 (60%)]	Losses net: reconstruction - 170.244064, latent - 2.519116
# Train Epoch: 12 [40000/50000 (80%)]	Losses net: reconstruction - 172.843475, latent - 2.565226
# Train Epoch: 12 [50000/50000 (100%)]	Losses net: reconstruction - 160.522934, latent - 2.378517
# Test set:
# net: loss: 163.433305	latent_loss: 0.025208
#
# Train Epoch: 13 [0/50000 (0%)]	Losses net: reconstruction - 163.168335, latent - 2.790593
# Train Epoch: 13 [10000/50000 (20%)]	Losses net: reconstruction - 154.626923, latent - 2.781988
# Train Epoch: 13 [20000/50000 (40%)]	Losses net: reconstruction - 171.575684, latent - 2.749917
# Train Epoch: 13 [30000/50000 (60%)]	Losses net: reconstruction - 178.595322, latent - 2.425055
# Train Epoch: 13 [40000/50000 (80%)]	Losses net: reconstruction - 146.755829, latent - 2.372777
# Train Epoch: 13 [50000/50000 (100%)]	Losses net: reconstruction - 161.154480, latent - 1.979230
# Test set:
# net: loss: 159.844136	latent_loss: 0.025215
#
# Train Epoch: 14 [0/50000 (0%)]	Losses net: reconstruction - 173.977493, latent - 2.506818
# Train Epoch: 14 [10000/50000 (20%)]	Losses net: reconstruction - 152.978088, latent - 2.175550
# Train Epoch: 14 [20000/50000 (40%)]	Losses net: reconstruction - 169.601212, latent - 2.501903
# Train Epoch: 14 [30000/50000 (60%)]	Losses net: reconstruction - 173.968643, latent - 2.128451
# Train Epoch: 14 [40000/50000 (80%)]	Losses net: reconstruction - 164.692505, latent - 2.594341
# Train Epoch: 14 [50000/50000 (100%)]	Losses net: reconstruction - 164.680618, latent - 2.647542
# Test set:
# net: loss: 157.155188	latent_loss: 0.026190
#
# Train Epoch: 15 [0/50000 (0%)]	Losses net: reconstruction - 168.046371, latent - 1.948724
# Train Epoch: 15 [10000/50000 (20%)]	Losses net: reconstruction - 147.633087, latent - 2.692753
# Train Epoch: 15 [20000/50000 (40%)]	Losses net: reconstruction - 166.316147, latent - 3.198395
# Train Epoch: 15 [30000/50000 (60%)]	Losses net: reconstruction - 155.087936, latent - 2.903061
# Train Epoch: 15 [40000/50000 (80%)]	Losses net: reconstruction - 154.988297, latent - 2.463246
# Train Epoch: 15 [50000/50000 (100%)]	Losses net: reconstruction - 155.966904, latent - 2.681790
# Test set:
# net: loss: 154.794739	latent_loss: 0.025072
#
# Train Epoch: 16 [0/50000 (0%)]	Losses net: reconstruction - 152.572388, latent - 2.418811
# Train Epoch: 16 [10000/50000 (20%)]	Losses net: reconstruction - 155.342896, latent - 2.430820
# Train Epoch: 16 [20000/50000 (40%)]	Losses net: reconstruction - 161.571640, latent - 2.145455
# Train Epoch: 16 [30000/50000 (60%)]	Losses net: reconstruction - 156.594711, latent - 2.365054
# Train Epoch: 16 [40000/50000 (80%)]	Losses net: reconstruction - 152.541031, latent - 2.598768
# Train Epoch: 16 [50000/50000 (100%)]	Losses net: reconstruction - 156.561142, latent - 2.374336
# Test set:
# net: loss: 152.794204	latent_loss: 0.024859
#
# Train Epoch: 17 [0/50000 (0%)]	Losses net: reconstruction - 146.283798, latent - 2.529912
# Train Epoch: 17 [10000/50000 (20%)]	Losses net: reconstruction - 162.886536, latent - 2.478270
# Train Epoch: 17 [20000/50000 (40%)]	Losses net: reconstruction - 141.274353, latent - 2.894792
# Train Epoch: 17 [30000/50000 (60%)]	Losses net: reconstruction - 161.592117, latent - 2.701933
# Train Epoch: 17 [40000/50000 (80%)]	Losses net: reconstruction - 144.362640, latent - 2.543839
# Train Epoch: 17 [50000/50000 (100%)]	Losses net: reconstruction - 156.198700, latent - 2.338304
# Test set:
# net: loss: 151.330637	latent_loss: 0.025095
#
# Train Epoch: 18 [0/50000 (0%)]	Losses net: reconstruction - 124.963127, latent - 2.081936
# Train Epoch: 18 [10000/50000 (20%)]	Losses net: reconstruction - 146.080811, latent - 2.393836
# Train Epoch: 18 [20000/50000 (40%)]	Losses net: reconstruction - 148.563019, latent - 2.538556
# Train Epoch: 18 [30000/50000 (60%)]	Losses net: reconstruction - 141.533707, latent - 2.351830
# Train Epoch: 18 [40000/50000 (80%)]	Losses net: reconstruction - 150.474365, latent - 2.653967
# Train Epoch: 18 [50000/50000 (100%)]	Losses net: reconstruction - 148.713455, latent - 2.309535
# Test set:
# net: loss: 150.112198	latent_loss: 0.024988
#
# Train Epoch: 19 [0/50000 (0%)]	Losses net: reconstruction - 156.577637, latent - 2.452712
# Train Epoch: 19 [10000/50000 (20%)]	Losses net: reconstruction - 152.887070, latent - 2.447936
# Train Epoch: 19 [20000/50000 (40%)]	Losses net: reconstruction - 140.455170, latent - 2.911384
# Train Epoch: 19 [30000/50000 (60%)]	Losses net: reconstruction - 158.336639, latent - 1.984359
# Train Epoch: 19 [40000/50000 (80%)]	Losses net: reconstruction - 137.177246, latent - 2.205828
# Train Epoch: 19 [50000/50000 (100%)]	Losses net: reconstruction - 147.390213, latent - 2.146749
# Test set:
# net: loss: 148.742913	latent_loss: 0.024779
#
# Train Epoch: 20 [0/50000 (0%)]	Losses net: reconstruction - 150.101120, latent - 2.398072
# Train Epoch: 20 [10000/50000 (20%)]	Losses net: reconstruction - 140.664169, latent - 2.836327
# Train Epoch: 20 [20000/50000 (40%)]	Losses net: reconstruction - 140.393021, latent - 2.517448
# Train Epoch: 20 [30000/50000 (60%)]	Losses net: reconstruction - 131.279434, latent - 2.731467
# Train Epoch: 20 [40000/50000 (80%)]	Losses net: reconstruction - 149.214935, latent - 2.267538
# Train Epoch: 20 [50000/50000 (100%)]	Losses net: reconstruction - 165.608597, latent - 2.592451
# Test set:
# net: loss: 147.502807	latent_loss: 0.024851
#
# Train Epoch: 21 [0/50000 (0%)]	Losses net: reconstruction - 151.035522, latent - 2.725008
# Train Epoch: 21 [10000/50000 (20%)]	Losses net: reconstruction - 135.640610, latent - 2.553780
# Train Epoch: 21 [20000/50000 (40%)]	Losses net: reconstruction - 137.809479, latent - 2.605399
# Train Epoch: 21 [30000/50000 (60%)]	Losses net: reconstruction - 147.492783, latent - 2.276776
# Train Epoch: 21 [40000/50000 (80%)]	Losses net: reconstruction - 146.020706, latent - 2.555604
# Train Epoch: 21 [50000/50000 (100%)]	Losses net: reconstruction - 144.360413, latent - 2.869316
# Test set:
# net: loss: 146.773322	latent_loss: 0.024273
#
# Train Epoch: 22 [0/50000 (0%)]	Losses net: reconstruction - 166.305984, latent - 2.208322
# Train Epoch: 22 [10000/50000 (20%)]	Losses net: reconstruction - 132.246033, latent - 2.261722
# Train Epoch: 22 [20000/50000 (40%)]	Losses net: reconstruction - 153.011505, latent - 2.544558
# Train Epoch: 22 [30000/50000 (60%)]	Losses net: reconstruction - 139.972748, latent - 2.670337
# Train Epoch: 22 [40000/50000 (80%)]	Losses net: reconstruction - 147.245880, latent - 2.675071
# Train Epoch: 22 [50000/50000 (100%)]	Losses net: reconstruction - 132.670517, latent - 3.230515
# Test set:
# net: loss: 146.222939	latent_loss: 0.024504
#
# Train Epoch: 23 [0/50000 (0%)]	Losses net: reconstruction - 153.418289, latent - 2.306288
# Train Epoch: 23 [10000/50000 (20%)]	Losses net: reconstruction - 137.616974, latent - 3.344367
# Train Epoch: 23 [20000/50000 (40%)]	Losses net: reconstruction - 143.930771, latent - 2.041768
# Train Epoch: 23 [30000/50000 (60%)]	Losses net: reconstruction - 148.315994, latent - 2.038013
# Train Epoch: 23 [40000/50000 (80%)]	Losses net: reconstruction - 139.032990, latent - 2.996672
# Train Epoch: 23 [50000/50000 (100%)]	Losses net: reconstruction - 127.438347, latent - 2.886354
# Test set:
# net: loss: 145.204148	latent_loss: 0.024557
#
# Train Epoch: 24 [0/50000 (0%)]	Losses net: reconstruction - 134.911179, latent - 2.607800
# Train Epoch: 24 [10000/50000 (20%)]	Losses net: reconstruction - 151.234329, latent - 2.762979
# Train Epoch: 24 [20000/50000 (40%)]	Losses net: reconstruction - 152.339203, latent - 1.814030
# Train Epoch: 24 [30000/50000 (60%)]	Losses net: reconstruction - 143.450485, latent - 2.704289
# Train Epoch: 24 [40000/50000 (80%)]	Losses net: reconstruction - 127.408104, latent - 2.393570
# Train Epoch: 24 [50000/50000 (100%)]	Losses net: reconstruction - 135.894318, latent - 2.797181
# Test set:
# net: loss: 144.465165	latent_loss: 0.024043
#
# Train Epoch: 25 [0/50000 (0%)]	Losses net: reconstruction - 145.153351, latent - 2.323727
# Train Epoch: 25 [10000/50000 (20%)]	Losses net: reconstruction - 147.854172, latent - 2.215864
# Train Epoch: 25 [20000/50000 (40%)]	Losses net: reconstruction - 149.538025, latent - 2.406055
# Train Epoch: 25 [30000/50000 (60%)]	Losses net: reconstruction - 139.858459, latent - 2.837931
# Train Epoch: 25 [40000/50000 (80%)]	Losses net: reconstruction - 136.392044, latent - 2.606283
# Train Epoch: 25 [50000/50000 (100%)]	Losses net: reconstruction - 126.831383, latent - 2.502790
# Test set:
# net: loss: 143.889533	latent_loss: 0.024642
#
# Train Epoch: 26 [0/50000 (0%)]	Losses net: reconstruction - 133.027618, latent - 2.214794
# Train Epoch: 26 [10000/50000 (20%)]	Losses net: reconstruction - 156.208099, latent - 2.210592
# Train Epoch: 26 [20000/50000 (40%)]	Losses net: reconstruction - 140.996170, latent - 3.094577
# Train Epoch: 26 [30000/50000 (60%)]	Losses net: reconstruction - 133.817001, latent - 2.853159
# Train Epoch: 26 [40000/50000 (80%)]	Losses net: reconstruction - 160.733261, latent - 3.051013
# Train Epoch: 26 [50000/50000 (100%)]	Losses net: reconstruction - 146.433304, latent - 2.870612
# Test set:
# net: loss: 143.138295	latent_loss: 0.024279
#
# Train Epoch: 27 [0/50000 (0%)]	Losses net: reconstruction - 150.349884, latent - 2.540615
# Train Epoch: 27 [10000/50000 (20%)]	Losses net: reconstruction - 133.822052, latent - 2.554649
# Train Epoch: 27 [20000/50000 (40%)]	Losses net: reconstruction - 154.666656, latent - 2.089542
# Train Epoch: 27 [30000/50000 (60%)]	Losses net: reconstruction - 135.863007, latent - 2.877849
# Train Epoch: 27 [40000/50000 (80%)]	Losses net: reconstruction - 148.670395, latent - 2.172773
# Train Epoch: 27 [50000/50000 (100%)]	Losses net: reconstruction - 136.816116, latent - 3.309011
# Test set:
# net: loss: 142.721587	latent_loss: 0.024853
#
# Train Epoch: 28 [0/50000 (0%)]	Losses net: reconstruction - 148.693222, latent - 2.652196
# Train Epoch: 28 [10000/50000 (20%)]	Losses net: reconstruction - 146.389771, latent - 2.054641
# Train Epoch: 28 [20000/50000 (40%)]	Losses net: reconstruction - 154.156601, latent - 3.474092
# Train Epoch: 28 [30000/50000 (60%)]	Losses net: reconstruction - 149.053497, latent - 2.315967
# Train Epoch: 28 [40000/50000 (80%)]	Losses net: reconstruction - 150.228439, latent - 3.085850
# Train Epoch: 28 [50000/50000 (100%)]	Losses net: reconstruction - 135.339249, latent - 2.168191
# Test set:
# net: loss: 142.422598	latent_loss: 0.024000
#
# Train Epoch: 29 [0/50000 (0%)]	Losses net: reconstruction - 121.395813, latent - 3.765920
# Train Epoch: 29 [10000/50000 (20%)]	Losses net: reconstruction - 143.817734, latent - 2.411916
# Train Epoch: 29 [20000/50000 (40%)]	Losses net: reconstruction - 144.398743, latent - 2.705186
# Train Epoch: 29 [30000/50000 (60%)]	Losses net: reconstruction - 153.848724, latent - 2.156718
# Train Epoch: 29 [40000/50000 (80%)]	Losses net: reconstruction - 147.981964, latent - 2.088327
# Train Epoch: 29 [50000/50000 (100%)]	Losses net: reconstruction - 130.169342, latent - 2.895771
# Test set:
# net: loss: 142.225137	latent_loss: 0.024764
#
# Train Epoch: 30 [0/50000 (0%)]	Losses net: reconstruction - 141.641083, latent - 2.698926
# Train Epoch: 30 [10000/50000 (20%)]	Losses net: reconstruction - 139.121658, latent - 2.463727
# Train Epoch: 30 [20000/50000 (40%)]	Losses net: reconstruction - 144.005280, latent - 2.073482
# Train Epoch: 30 [30000/50000 (60%)]	Losses net: reconstruction - 146.546692, latent - 2.348699
# Train Epoch: 30 [40000/50000 (80%)]	Losses net: reconstruction - 133.338943, latent - 2.209407
# Train Epoch: 30 [50000/50000 (100%)]	Losses net: reconstruction - 133.271149, latent - 2.302641
# Test set:
# net: loss: 141.545765	latent_loss: 0.024391
#
# Train Epoch: 31 [0/50000 (0%)]	Losses net: reconstruction - 123.655785, latent - 2.556343
# Train Epoch: 31 [10000/50000 (20%)]	Losses net: reconstruction - 145.308075, latent - 2.488688
# Train Epoch: 31 [20000/50000 (40%)]	Losses net: reconstruction - 138.419617, latent - 2.210777
# Train Epoch: 31 [30000/50000 (60%)]	Losses net: reconstruction - 125.182877, latent - 3.094743
# Train Epoch: 31 [40000/50000 (80%)]	Losses net: reconstruction - 134.915405, latent - 2.649734
# Train Epoch: 31 [50000/50000 (100%)]	Losses net: reconstruction - 136.200806, latent - 2.147045
# Test set:
# net: loss: 141.190803	latent_loss: 0.024250
#
# Train Epoch: 32 [0/50000 (0%)]	Losses net: reconstruction - 132.784576, latent - 2.828981
# Train Epoch: 32 [10000/50000 (20%)]	Losses net: reconstruction - 132.355194, latent - 2.434619
# Train Epoch: 32 [20000/50000 (40%)]	Losses net: reconstruction - 138.669174, latent - 2.564231
# Train Epoch: 32 [30000/50000 (60%)]	Losses net: reconstruction - 135.933746, latent - 2.100961
# Train Epoch: 32 [40000/50000 (80%)]	Losses net: reconstruction - 148.274826, latent - 2.596369
# Train Epoch: 32 [50000/50000 (100%)]	Losses net: reconstruction - 132.254837, latent - 2.415612
# Test set:
# net: loss: 141.199038	latent_loss: 0.024687
#
# Train Epoch: 33 [0/50000 (0%)]	Losses net: reconstruction - 140.337036, latent - 2.402944
# Train Epoch: 33 [10000/50000 (20%)]	Losses net: reconstruction - 133.649750, latent - 1.994934
# Train Epoch: 33 [20000/50000 (40%)]	Losses net: reconstruction - 140.576843, latent - 2.137478
# Train Epoch: 33 [30000/50000 (60%)]	Losses net: reconstruction - 138.744705, latent - 2.373072
# Train Epoch: 33 [40000/50000 (80%)]	Losses net: reconstruction - 139.130325, latent - 1.821700
# Train Epoch: 33 [50000/50000 (100%)]	Losses net: reconstruction - 143.771378, latent - 2.388219
# Test set:
# net: loss: 140.553236	latent_loss: 0.024234
#
# Train Epoch: 34 [0/50000 (0%)]	Losses net: reconstruction - 140.712448, latent - 2.877637
# Train Epoch: 34 [10000/50000 (20%)]	Losses net: reconstruction - 136.770172, latent - 2.558272
# Train Epoch: 34 [20000/50000 (40%)]	Losses net: reconstruction - 137.001862, latent - 2.620142
# Train Epoch: 34 [30000/50000 (60%)]	Losses net: reconstruction - 154.494202, latent - 2.742687
# Train Epoch: 34 [40000/50000 (80%)]	Losses net: reconstruction - 127.887764, latent - 2.535439
# Train Epoch: 34 [50000/50000 (100%)]	Losses net: reconstruction - 145.977798, latent - 2.304837
# Test set:
# net: loss: 139.969785	latent_loss: 0.023505
#
# Train Epoch: 35 [0/50000 (0%)]	Losses net: reconstruction - 140.462158, latent - 2.728497
# Train Epoch: 35 [10000/50000 (20%)]	Losses net: reconstruction - 146.784988, latent - 2.707800
# Train Epoch: 35 [20000/50000 (40%)]	Losses net: reconstruction - 128.755173, latent - 2.451978
# Train Epoch: 35 [30000/50000 (60%)]	Losses net: reconstruction - 141.971466, latent - 2.442680
# Train Epoch: 35 [40000/50000 (80%)]	Losses net: reconstruction - 132.232620, latent - 2.530110
# Train Epoch: 35 [50000/50000 (100%)]	Losses net: reconstruction - 133.379013, latent - 2.299972
# Test set:
# net: loss: 139.860023	latent_loss: 0.023456
#
# Train Epoch: 36 [0/50000 (0%)]	Losses net: reconstruction - 139.788010, latent - 2.247354
# Train Epoch: 36 [10000/50000 (20%)]	Losses net: reconstruction - 136.824707, latent - 2.512583
# Train Epoch: 36 [20000/50000 (40%)]	Losses net: reconstruction - 136.955688, latent - 2.453339
# Train Epoch: 36 [30000/50000 (60%)]	Losses net: reconstruction - 133.762985, latent - 2.468925
# Train Epoch: 36 [40000/50000 (80%)]	Losses net: reconstruction - 140.385437, latent - 2.104806
# Train Epoch: 36 [50000/50000 (100%)]	Losses net: reconstruction - 134.423386, latent - 1.998425
# Test set:
# net: loss: 139.398316	latent_loss: 0.024082
#
# Train Epoch: 37 [0/50000 (0%)]	Losses net: reconstruction - 120.145218, latent - 2.809448
# Train Epoch: 37 [10000/50000 (20%)]	Losses net: reconstruction - 134.958084, latent - 1.947356
# Train Epoch: 37 [20000/50000 (40%)]	Losses net: reconstruction - 139.207153, latent - 1.958295
# Train Epoch: 37 [30000/50000 (60%)]	Losses net: reconstruction - 143.198013, latent - 2.854434
# Train Epoch: 37 [40000/50000 (80%)]	Losses net: reconstruction - 146.732788, latent - 2.687066
# Train Epoch: 37 [50000/50000 (100%)]	Losses net: reconstruction - 133.596756, latent - 2.328143
# Test set:
# net: loss: 139.248372	latent_loss: 0.023781
#
# Train Epoch: 38 [0/50000 (0%)]	Losses net: reconstruction - 140.649109, latent - 2.638528
# Train Epoch: 38 [10000/50000 (20%)]	Losses net: reconstruction - 137.771240, latent - 2.417568
# Train Epoch: 38 [20000/50000 (40%)]	Losses net: reconstruction - 129.551620, latent - 3.220246
# Train Epoch: 38 [30000/50000 (60%)]	Losses net: reconstruction - 137.916458, latent - 1.968156
# Train Epoch: 38 [40000/50000 (80%)]	Losses net: reconstruction - 135.937317, latent - 2.317292
# Train Epoch: 38 [50000/50000 (100%)]	Losses net: reconstruction - 143.651779, latent - 2.775206
# Test set:
# net: loss: 139.040385	latent_loss: 0.023558
#
# Train Epoch: 39 [0/50000 (0%)]	Losses net: reconstruction - 146.451523, latent - 2.208916
# Train Epoch: 39 [10000/50000 (20%)]	Losses net: reconstruction - 123.434319, latent - 1.933200
# Train Epoch: 39 [20000/50000 (40%)]	Losses net: reconstruction - 138.910599, latent - 2.391833
# Train Epoch: 39 [30000/50000 (60%)]	Losses net: reconstruction - 126.639381, latent - 2.299133
# Train Epoch: 39 [40000/50000 (80%)]	Losses net: reconstruction - 132.682190, latent - 2.099254
# Train Epoch: 39 [50000/50000 (100%)]	Losses net: reconstruction - 140.025452, latent - 2.297332
# Test set:
# net: loss: 139.066859	latent_loss: 0.023917
#
# Train Epoch: 40 [0/50000 (0%)]	Losses net: reconstruction - 144.006958, latent - 1.943634
# Train Epoch: 40 [10000/50000 (20%)]	Losses net: reconstruction - 136.590851, latent - 2.288421
# Train Epoch: 40 [20000/50000 (40%)]	Losses net: reconstruction - 136.129303, latent - 2.239650
# Train Epoch: 40 [30000/50000 (60%)]	Losses net: reconstruction - 143.336441, latent - 2.195598
# Train Epoch: 40 [40000/50000 (80%)]	Losses net: reconstruction - 125.073936, latent - 2.764474
# Train Epoch: 40 [50000/50000 (100%)]	Losses net: reconstruction - 135.795532, latent - 2.819072
# Test set:
# net: loss: 138.746752	latent_loss: 0.023299

# %%
data, _ = next(iter(test_loader))
output = models['net'](data)
to_plot = output.data.numpy() #данные с выхода сети

# %%
print('исходные данные')
plot_mnist(data.data.numpy(), (5, 10))
print('восстановленные данные')
plot_mnist(to_plot, (5, 10))
# Out:
# исходные данные
# восстановленные данные

# %%
latent = models['net'].E(data)

# %%
plt.scatter(latent.detach().numpy()[:, 0], latent.detach().numpy()[:, 1])

# %%
volume=20
x = np.repeat(np.linspace(-1, 3, num=volume, dtype=np.float32), volume)
y = np.tile(np.linspace(-3, 1, num=volume, dtype=np.float32), volume)
lat = torch.tensor(np.stack((x, y)).T)

# %%
lat_output = models['net'].D(lat)

# %%
plot_mnist(lat_output.data.numpy(), (volume, volume))
